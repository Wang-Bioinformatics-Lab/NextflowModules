# %%
import sys
import getopt
import os
import json
import argparse
import uuid
import pandas as pd
from collections import defaultdict

from gnps_index import *
from numba.typed import List
import numpy as np
from pyteomics import mgf
from library_search_indexed import read_mgf

# %%
spectra_path = "/home/user/LabData/Reza/Code/LibrarySearch_Workflow/data/spectra/selected.mgf"
library_path = "/home/user/LabData/Reza/Code/LibrarySearch_Workflow/data/libraries/rest.mgf"

# %%
spectrum_mgf = read_mgf(spectra_path)
# print(spectrum_mgf[0].keys())

library_mgf = read_mgf(library_path)

# %%
def convert_single_spectrum_to_spectrum_list(data_dict):
    mz = [float(x[0]) for x in data_dict['peaks']]
    intensity = [float(x[1]) for x in data_dict['peaks']]
    precursor_mz = float(data_dict.get('PEPMASS', 0.0))
    precursor_charge = data_dict.get('CHARGE', data_dict.get('charge', 1))
    precursor_charge = abs(int(precursor_charge))  # Ensure charge is positive
    # print("log", f"Converted spectrum with {len(mz)} peaks, precursor_mz: {precursor_mz}, precursor_charge: {precursor_charge}")
    # print("log", f"mz: {mz[:5]}, intensity: {intensity[:5]}")
    mz = np.asarray(mz, dtype=np.float32)
    intensity = np.asarray(intensity, dtype=np.float32)
    return filter_peaks_optimized(mz, intensity, precursor_mz, precursor_charge)

spectrum_list = [convert_single_spectrum_to_spectrum_list(spec) for spec in spectrum_mgf]
library_list = [convert_single_spectrum_to_spectrum_list(spec) for spec in library_mgf]

# %%
df = pd.DataFrame(library_mgf)
df.head(5)
# Out:
#    PEPMASS          SPECTRUMID SCANS  \
# 0  223.051  CCMSLIB00010101988   506
# 1  223.051  CCMSLIB00010101989   503
# 2  405.182  CCMSLIB00010101990   603
# 3  185.061  CCMSLIB00010101991   614
# 4  185.061  CCMSLIB00010101992   605
#
#                                                peaks  CHARGE MSLEVEL  \
# 0  [[66.79527, 2.340182], [74.76895, 2.3136747], ...      -1       2
# 1  [[74.99028, 16.873964], [79.957, 4.377357], [8...      -1       2
# 2  [[65.328674, 20.255243], [92.43383, 29.783403]...      -1       2
# 3  [[52.97066, 1.8730004], [54.45359, 1.9932256],...      -1       2
# 4  [[60.311302, 4.445654], [70.33653, 3.9257047],...      -1       2
#
#   SOURCE_INSTRUMENT                                           FILENAME   SEQ  \
# 0   LC-ESI-Orbitrap  tharwood/20220308_JGI-AK-TH_TN_507992_PlantStd...  *..*
# 1   LC-ESI-Orbitrap  tharwood/20220308_JGI-AK-TH_TN_507992_PlantStd...  *..*
# 2   LC-ESI-Orbitrap  tharwood/20220308_JGI-AK-TH_TN_507992_PlantStd...  *..*
# 3   LC-ESI-Orbitrap  tharwood/20220308_JGI-AK-TH_TN_507992_PlantStd...  *..*
# 4   LC-ESI-Orbitrap  tharwood/20220308_JGI-AK-TH_TN_507992_PlantStd...  *..*
#
#     IONMODE  ...                                               NAME  \
# 0  Negative  ...  Phenazine-1-carboxylic acid CollisionEnergy:10...
# 1  Negative  ...  Phenazine-1-carboxylic acid CollisionEnergy:20...
# 2  Negative  ...  indole-3-butyric acid CollisionEnergy:102040 2M-H
# 3  Negative  ...  1-Naphthaleneacetic acid CollisionEnergy:10204...
# 4  Negative  ...  1-Naphthaleneacetic acid CollisionEnergy:20506...
#
#               PI DATACOLLECTOR                                 SMILES  \
# 0  Trent Northen           JGI  C1=CC=C2C(=C1)N=C3C=CC=C(C3=N2)C(=O)O
# 1  Trent Northen           JGI  C1=CC=C2C(=C1)N=C3C=CC=C(C3=N2)C(=O)O
# 2  Trent Northen           JGI         C1=CC=C2C(=C1)C(=CN2)CCCC(=O)O
# 3  Trent Northen           JGI           C1=CC=C2C(=C1)C=CC=C2CC(=O)O
# 4  Trent Northen           JGI           C1=CC=C2C(=C1)C=CC=C2CC(=O)O
#
#                                                INCHI INCHIAUX PUBMED  \
# 0  "InChI=1S/C13H8N2O2/c16-13(17)8-4-3-7-11-12(8)...      N/A    N/A
# 1  "InChI=1S/C13H8N2O2/c16-13(17)8-4-3-7-11-12(8)...      N/A    N/A
# 2  "InChI=1S/C12H13NO2/c14-12(15)7-3-4-9-8-13-11-...      N/A    N/A
# 3  "InChI=1S/C12H10O2/c13-12(14)8-10-6-3-5-9-4-1-...      N/A    N/A
# 4  "InChI=1S/C12H10O2/c13-12(14)8-10-6-3-5-9-4-1-...      N/A    N/A
#
#   SUBMITUSER LIBRARYQUALITY PRECURSOR_MZ
# 0    mwang87              3      223.051
# 1    mwang87              3      223.051
# 2    mwang87              3      405.182
# 3    mwang87              3      185.061
# 4    mwang87              3      185.061
#
# [5 rows x 21 columns]

# %%
library_list
# Out:
# [(array([ 66.79527 ,  74.76895 ,  79.18015 ,  86.134895,  87.82698 ,
#           96.95974 , 121.07147 , 147.412   , 155.0611  , 167.06174 ,
#          179.0614  , 180.06677 , 182.04811 , 183.05711 , 195.05638 ,
#          197.07204 , 198.07706 , 205.01732 , 223.0284  , 223.05179 ,
#          223.10103 , 224.05627 ], dtype=float32),
#   array([0.03515802, 0.03495833, 0.03712093, 0.03435741, 0.03642141,
#          0.05856638, 0.03914803, 0.03691255, 0.10134196, 0.08004299,
#          0.4400461 , 0.04054559, 0.05396103, 0.08639131, 0.2676156 ,
#          0.72641087, 0.05568074, 0.09167421, 0.28776908, 0.25768742,
#          0.04711797, 0.05258903], dtype=float32),
#   223.051,
#   1),
#  (array([ 74.99028,  79.957  ,  85.29974,  93.00113,  96.95953, 129.26405,
#          149.00882, 155.06113, 167.06093, 178.05325, 179.06093, 182.04813,
#          183.05539, 195.0558 , 197.07156, 198.07466, 205.01703, 206.99689,
#          211.44548, 223.02745, 223.05089, 224.05705], dtype=float32),
#   array([0.09447905, 0.04812081, 0.04237027, 0.05097555, 0.06453754,
#          0.04683856, 0.09826987, 0.09213664, 0.10091853, 0.14358921,
#          0.42519203, 0.05251258, 0.0751009 , 0.28357998, 0.7269587 ,
#          0.06063142, 0.06569593, 0.06958482, 0.05246531, 0.20424646,
#          0.2644962 , 0.06101478], dtype=float32),
#   223.051,
#   1),
#  (array([ 65.328674,  92.43383 , 113.988976, 137.32664 , 145.56732 ,
#          152.73944 , 154.01605 , 158.09834 , 202.08748 , 203.09196 ,
#          287.32925 , 319.1374  , 387.16217 , 405.17313 ], dtype=float32),
#   array([0.10579104, 0.12828247, 0.11264492, 0.10528331, 0.10688161,
#          0.11566141, 0.11276243, 0.15097484, 0.7429557 , 0.1412054 ,
#          0.12891361, 0.13899717, 0.14712934, 0.508685  ], dtype=float32),
#   405.182,
#   1),
#  (array([ 52.97066 ,  54.45359 ,  93.706535,  97.066246,  99.92574 ,
#          104.362236, 110.50521 , 115.9204  , 123.081696, 141.07097 ,
#          142.07465 , 143.04982 , 185.01079 , 185.02875 , 185.06071 ,
#          185.0795  , 185.118   , 185.1563  , 199.85175 , 203.6859  ,
#          209.93294 , 383.3413  ], dtype=float32),
#   array([0.04153468, 0.04284697, 0.04350718, 0.0444454 , 0.07606287,
#          0.04826049, 0.04323922, 0.06436975, 0.05061006, 0.95923424,
#          0.10676985, 0.0564025 , 0.05498989, 0.05240783, 0.11471941,
#          0.06157867, 0.07963224, 0.04794385, 0.05464074, 0.04380631,
#          0.05256309, 0.04626095], dtype=float32),
#   185.061,
#   1),
#  (array([ 60.311302,  70.33653 ,  72.31466 ,  97.06547 ,  99.92573 ,
#          114.3745  , 136.28711 , 141.07103 , 142.07433 , 143.0499  ,
#          161.95085 , 185.01178 , 185.02992 , 185.06097 , 185.11774 ,
#          209.8918  ], dtype=float32),
#   array([0.06366194, 0.05982337, 0.05910511, 0.07507141, 0.08604898,
#          0.06400958, 0.06635536, 0.9543217 , 0.09334078, 0.09153446,
#          0.06293993, 0.07777294, 0.06758577, 0.11308996, 0.07998206,
#          0.07582282], dtype=float32),
#   185.061,
#   1),
#  (array([ 56.43707 ,  70.760155,  82.06633 , 116.05042 , 158.09718 ,
#          202.08722 , 218.70445 , 405.17316 ], dtype=float32),
#   array([0.16690525, 0.15879439, 0.15983333, 0.32520902, 0.300376  ,
#          0.78293234, 0.17977007, 0.2830077 ], dtype=float32),
#   405.182,
#   1),
#  (array([ 59.013252,  61.00994 ,  71.01333 ,  78.91025 ,  92.43374 ,
#          122.32822 , 139.62735 , 141.0708  , 177.05785 , 184.56635 ,
#          189.0573  , 191.07304 , 193.016   , 207.06757 , 219.69966 ,
#          311.2228  , 342.41507 , 353.0706  , 371.13626 , 371.24527 ,
#          394.9937  ], dtype=float32),
#   array([0.0857668 , 0.09076923, 0.13783439, 0.08525899, 0.0957668 ,
#          0.0836135 , 0.0933079 , 0.16230628, 0.13783075, 0.09060502,
#          0.2149974 , 0.10715354, 0.10450454, 0.21234931, 0.08743303,
#          0.11190183, 0.08870485, 0.0908527 , 0.8313704 , 0.17707069,
#          0.08473177], dtype=float32),
#   371.129,
#   1),
#  (array([ 59.013382,  61.009727,  66.72273 ,  67.121025,  71.01355 ,
#           75.45782 ,  81.03406 ,  85.009926,  85.029076,  89.02423 ,
#           97.029175,  99.02575 , 101.024086, 113.02339 , 141.07074 ,
#          171.04678 , 175.00662 , 177.05731 , 189.0574  , 191.07419 ,
#          193.0172  , 207.06773 , 215.29474 , 311.22272 , 371.1362  ,
#          371.2444  , 393.00314 ], dtype=float32),
#          0.02960096, 0.0748293 , 0.03323257, 0.04125644, 0.03251014,
#          0.03133994, 0.03311035, 0.02979115, 0.06694083, 0.03437626,
#          0.08388866, 0.03074441, 0.04543376, 0.26176262, 0.03245835,
#          0.108509  , 0.03127089, 0.13612755, 0.5442626 ], dtype=float32),
#   428.037,
#   1),
#  (array([ 50.1998,  50.3947,  65.2833,  70.467 ,  82.1762,  92.3871,
#           98.9844, 108.012 , 111.869 , 116.871 , 126.022 , 141.342 ,
#          227.646 , 241.987 ], dtype=float32),
#   array([0.08722143, 0.08097186, 0.07768477, 0.07856863, 0.07871446,
#          0.09305394, 0.2631953 , 0.12289382, 0.08682793, 0.08673165,
#          0.9109838 , 0.08169355, 0.08649718, 0.12365157], dtype=float32),
#   251.037,
#   1),
#  (array([ 62.3993,  68.751 ,  76.7415,  82.4925,  92.3892, 104.3   ,
#          108.012 , 108.996 , 126.022 ], dtype=float32),
#   array([0.05903455, 0.0520287 , 0.05900234, 0.05330101, 0.0743127 ,
#          0.06119249, 0.5875171 , 0.126048  , 0.7855917 ], dtype=float32),
#   126.022,
#   1),
#  (array([ 52.5198,  60.8503,  68.72  ,  70.2086,  73.9592,  75.9912,
#          108.012 , 108.081 ], dtype=float32),
#   array([0.140612  , 0.16459902, 0.14739873, 0.14460024, 0.16788574,
#          0.1466419 , 0.54072374, 0.7539418 ], dtype=float32),
#   108.011,
#   1),
#  (array([ 50.8604,  52.8899,  82.0741,  86.892 ,  90.2165,  97.1641,
#          104.302 , 120.081 , 124.042 , 145.409 , 148.004 , 148.079 ,
#          148.111 ], dtype=float32),
#   array([0.05999379, 0.05895952, 0.06437199, 0.06403423, 0.06709994,
#          0.06070055, 0.06225063, 0.07757398, 0.26879132, 0.06490823,
#          0.2626073 , 0.882078  , 0.2076402 ], dtype=float32),
#   148.004,
#   1),
#  (array([ 64.8873,  92.3887, 100.177 , 115.559 , 122.46  , 150.503 ,
#          169.986 , 170.06  , 170.096 ], dtype=float32),
#   array([0.08321735, 0.09460123, 0.08411795, 0.08625201, 0.08472952,
#          0.08112515, 0.9484363 , 0.12284233, 0.20304741], dtype=float32),
#   169.986,
#   1),
#  (array([ 66.9754, 102.588 , 118.035 , 122.618 , 132.659 , 136.246 ,
#          158.012 , 178.027 , 185.445 , 222.055 , 225.019 , 234.054 ,
#          243.029 , 257.01  , 275.02  , 277.06  , 287.045 , 305.055 ,
#          318.088 , 321.087 , 323.065 , 339.097 , 401.13  ], dtype=float32),
#   array([0.04517036, 0.04218823, 0.04231104, 0.04104822, 0.04711294,
#          0.0500202 , 0.06393771, 0.04589899, 0.04409902, 0.06009911,
#          0.09268712, 0.04705795, 0.11729719, 0.04172821, 0.05275157,
#          0.05743772, 0.08218268, 0.1684511 , 0.05081185, 0.17866082,
#          0.08320183, 0.27924606, 0.8884325 ], dtype=float32),
#   401.133,
#   1),
#  (array([ 60.5543,  61.1348,  65.5645,  66.7609,  70.0658,  73.974 ,
#           82.4212,  92.4034,  97.5071, 110.071 , 115.087 , 157.937 ,
#          0.07688697, 0.03777263, 0.26884964, 0.05325109, 0.03486212,
#          0.03650182, 0.252086  , 0.11427019, 0.04524563, 0.13465586,
#          0.07873266, 0.03961696], dtype=float32),
#   156.102,
#   1),
#  (array([ 64.0472,  65.0392,  66.7473,  67.0549,  92.0499,  92.3848,
#           93.0577,  94.0655,  96.0447, 104.297 , 110.06  , 121.539 ,
#          131.272 , 136.009 , 138.055 , 138.477 ], dtype=float32),
#   array([0.03132705, 0.04088581, 0.02790353, 0.03977227, 0.11784017,
#          0.03992766, 0.03932124, 0.23484942, 0.07689308, 0.03385955,
#          0.20190455, 0.03163597, 0.02983269, 0.03163991, 0.93304694,
#          0.0388915 ], dtype=float32),
#   138.055,
#   1),
#  (array([ 61.0114,  66.8252,  69.0341,  70.8394,  73.9504,  75.027 ,
#           92.3773,  97.0287, 101.76  , 103.022 , 118.497 , 119.611 ,
#          136.062 , 145.032 , 163.042 , 208.606 , 218.849 , 250.285 ,
#          298.096 ], dtype=float32),
#   array([0.19624706, 0.03371298, 0.04170655, 0.03332458, 0.03558395,
#          0.11793549, 0.03723321, 0.13444427, 0.03386247, 0.0539437 ,
#          0.03460253, 0.032914  , 0.81609344, 0.16780038, 0.18253817,
#          0.03477655, 0.03613234, 0.03394748, 0.4305506 ], dtype=float32),
#   298.097,
#   1),
#  (array([ 54.3279,  79.9848,  82.4173,  89.949 ,  92.3971,  93.9429,
#           96.9955,  97.995 , 124.938 , 136.24  , 136.623 , 142.948 ,
#          165.128 , 168.068 , 169.072 , 170.979 , 176.972 , 187.094 ,
#          196.958 , 201.989 , 212.99  , 224.99  , 243.    , 252.453 ,
#          271.031 , 271.081 , 288.859 , 289.042 , 289.094 ], dtype=float32),
#   array([0.02991074, 0.03625347, 0.03640317, 0.03172722, 0.0304412 ,
#          0.03204801, 0.09989326, 0.07270268, 0.30817455, 0.03390196,
#          0.03106833, 0.30516663, 0.03234228, 0.07309489, 0.06422732,
#          0.08481849, 0.03207513, 0.10557072, 0.0960068 , 0.04854947,
#          0.08887886, 0.06926688, 0.25937578, 0.032257  , 0.5539784 ,
#          0.25579804, 0.03725947, 0.38345775, 0.38053295], dtype=float32),
#   289.042,
#   1),
#  (array([ 73.029 ,  73.9689,  98.9845, 101.06  , 107.384 , 118.678 ,
#          120.966 , 123.042 , 136.239 , 141.052 , 148.998 , 174.977 ,
#          184.889 , 184.98  , 221.018 , 267.06  ], dtype=float32),
#   array([0.07393281, 0.05092765, 0.05472944, 0.06603703, 0.05036327,
#          0.04986091, 0.2721809 , 0.6446639 , 0.05422655, 0.10873456,
#          0.1376924 , 0.2059015 , 0.05767106, 0.05427128, 0.6136759 ,
#          0.17578314], dtype=float32),
#   267.06,
#   1),
#  (array([ 63.3534,  82.3971, 104.283 , 107.049 , 108.451 , 111.044 ,
#          122.763 , 126.331 , 135.044 , 139.028 , 139.039 , 152.071 ,
#          157.974 , 163.039 , 181.049 , 198.076 ], dtype=float32),
#   array([0.05933433, 0.06947565, 0.06921671, 0.08267967, 0.06118866,
#          0.09633225, 0.0639637 , 0.06248144, 0.32451528, 0.08930862,
#          0.39464214, 0.67428386, 0.07127116, 0.18483643, 0.39525515,
#          0.1996205 ], dtype=float32),
#   198.076,
#   1),
#  (array([ 50.4297,  62.9823,  66.7577,  72.8284,  82.4183,  89.0056,
#           92.3981, 104.305 , 104.313 , 109.379 , 118.681 , 121.769 ,
#          129.029 , 130.515 , 173.018 , 191.029 , 191.153 ], dtype=float32),
#   array([0.06078525, 0.23519325, 0.07453423, 0.06711449, 0.07547173,
#          0.06714156, 0.06641036, 0.07180375, 0.07441968, 0.07123025,
#          0.07596816, 0.06429672, 0.17292167, 0.0647267 , 0.21398741,
#          0.8949256 , 0.09933981], dtype=float32),
#   191.029,
#   1),
#  (array([ 50.7143,  53.6118,  66.0788,  80.05  ,  80.2029,  82.4142,
#           92.3947,  95.0367,  99.4304, 104.305 , 107.154 , 108.045 ,
#          109.927 , 118.693 , 123.032 , 136.039 , 136.234 , 154.05  ],
#         dtype=float32),
#   array([0.03185763, 0.03173448, 0.03543679, 0.08787931, 0.0331539 ,
#          0.0384988 , 0.03885404, 0.04548872, 0.03656362, 0.04498105,
#          0.03424015, 0.14261743, 0.03412712, 0.04031324, 0.06781957,
#          0.9671419 , 0.04098292, 0.11633775], dtype=float32),
#   154.05,
#   1),
#  ...]

# %%
def convert_to_mamba_format(file_list):
    numba_spectra = List()
    for spec in file_list:
        numba_spectra.append((
            spec[0].astype(np.float32),
            spec[1].astype(np.float32),
            np.float32(spec[2]),
            np.int32(spec[3])
        ))
    n_spectra = len(numba_spectra)
    return numba_spectra, n_spectra

@numba.njit
def cross_library_compute_all_pairs(spectra, library, shared_entries,
                                    shifted_entries, tolerance,
                                    threshold, topk,
                                    library_min_matched_peaks):
    results = List()

    n_library = len(library)
    n_spectra = len(spectra)
    for query_idx in range(n_spectra):
        print(f"Processing query spectrum {query_idx + 1}/{n_spectra}...")
        query_spec = spectra[query_idx]
        upper_bounds = np.zeros(n_library, dtype=np.float32)
        match_counts = np.zeros(n_library, dtype=np.int32)

        # Process both shared and shifted peaks
        for peak_idx in range(len(query_spec[0])):
            mz = query_spec[0][peak_idx]
            intensity = query_spec[1][peak_idx]
            precursor_mz = query_spec[2]

            # Shared peaks processing
            shared_bin = np.int64(round(mz / tolerance))
            shifted_bin = np.int64(round((precursor_mz - mz + SHIFTED_OFFSET) / tolerance))

            # Check both shared and shifted entries
            for entries, bin_val in [(shared_entries, shared_bin),
                                     (shifted_entries, shifted_bin)]:
                for delta in ADJACENT_BINS:
                    target_bin = bin_val + delta
                    start, end = find_bin_range(entries, target_bin)
                    pos = start
                    while pos < end and entries[pos][1] <= query_idx:
                        pos += 1
                    # Find matches in this bin
                    while pos < end and entries[pos][0] == target_bin:
                        spec_idx = entries[pos][1]
                        upper_bounds[spec_idx] += intensity * entries[pos][4]
                        match_counts[spec_idx] += 1
                        pos += 1
        # print("log", f"Upper bounds for query {query_idx}: {len(upper_bounds)}")
        # Collect candidates using threshold parameter
        candidates = List()
        for lib_idx in range(n_library):
            if lib_idx == 10748:
                print(upper_bounds[lib_idx], match_counts[lib_idx])
            if (upper_bounds[lib_idx] >= threshold and
                    match_counts[lib_idx] >= library_min_matched_peaks):
                candidates.append((lib_idx, upper_bounds[lib_idx]))
        
        # print("log", f"Candidates for query {query_idx}: {len(candidates)}")
        # for item in candidates:
        #     print("log", f"Candidate: {item[0]}, Score: {item[1]}")
        # Sort candidates by upper bound score
        candidates.sort(key=lambda x: -x[1])
        # print("log", f"sorted candidates")
        print("candidates", candidates)
        # Process top candidates for exact matching
        exact_matches = List()
        for lib_idx, _ in candidates:
            # print("log", f"Processing exact match for candidate {lib_idx}...")
            target_spec = library[lib_idx]
            score, shared, shifted, num_matches = calculate_exact_score_GNPS(spectra[query_idx], target_spec, tolerance)
            # score is of type <object type:float64> print it in log as a float value human readable
            print("log", f"Score for candidate {lib_idx}:", score.item())
            if score >= threshold:
                exact_matches.append((lib_idx, score, shared, shifted, num_matches))

        # Sort and store top results
        exact_matches.sort(key=lambda x: -x[1])
        results.append((query_idx, exact_matches[:topk]))

    return results

# %%
spectrum_list = spectrum_list[0:1]
converted_spectrum_list, num_spectra = convert_to_mamba_format(spectrum_list)
converted_library_list, num_library = convert_to_mamba_format(library_list)

library_shared_idx = create_index(converted_library_list, False, 0.5, SHIFTED_OFFSET)
library_shifted_idx = create_index(converted_library_list, True, 0.5, SHIFTED_OFFSET)

# %%
matches = cross_library_compute_all_pairs(converted_spectrum_list,
                                              converted_library_list,
                                              library_shared_idx,
                                              library_shifted_idx,
                                tolerance=0.5, threshold=0.7, topk=1, library_min_matched_peaks=6)
# Out:
# Processing query spectrum 1/1...
# 1.9671087265014648 51
# candidates [(10748, 1.9671087265014648), (22041, 1.7978641986846924), (1072, 1.0298961400985718), (24643, 1.0298961400985718), (19398, 0.9269737005233765), (8081, 0.9211397171020508), (1643, 0.9182926416397095), (4325, 0.9124040603637695), (1594, 0.9032070636749268), (15646, 0.895987868309021), (12920, 0.8232729434967041), (173, 0.811319887638092), (172, 0.8040243983268738), (8279, 0.8000421524047852), (10842, 0.785700798034668), (2848, 0.7791898250579834), (10818, 0.7790063619613647), (17809, 0.7613140940666199), (2055, 0.7549872398376465), (1762, 0.7492693662643433), (24739, 0.7479681968688965), (1168, 0.7479681968688965), (4534, 0.7439603209495544), (3035, 0.7284307479858398), (8876, 0.7262328863143921), (10980, 0.7216756939888), (24818, 0.7209244966506958), (1247, 0.7209244966506958), (4204, 0.7192760705947876), (6493, 0.7153799533843994), (20957, 0.7138700485229492), (12853, 0.7119367122650146), (22271, 0.7116252183914185), (15599, 0.7114931344985962), (1525, 0.709837794303894), (1420, 0.7088780403137207), (19896, 0.7071642875671387), (12748, 0.7056907415390015), (4110, 0.7040377259254456), (21214, 0.7024686336517334), ...]
# log Score for candidate 10748: 0.9660447175847366
# log Score for candidate 22041: 0.8467328703263775
# log Score for candidate 1072: 0.8506355340359733
# log Score for candidate 24643: 0.8506355340359733
# log Score for candidate 19398: 0.577969269361347
# log Score for candidate 8081: 0.5739641182590276
# log Score for candidate 1643: 0.5720661965897307
# log Score for candidate 4325: 0.5750779905356467
# log Score for candidate 1594: 0.4652606808813289
# log Score for candidate 15646: 0.5579030625522137
# log Score for candidate 12920: 0.41746703517856076
# log Score for candidate 173: 0.4082854572334327
# log Score for candidate 172: 0.3880162359564565
# log Score for candidate 8279: 0.4918620222597383
# log Score for candidate 10842: 0.4000078847166151
# log Score for candidate 2848: 0.4874112708494067
# log Score for candidate 10818: 0.4828829341568053
# log Score for candidate 17809: 0.36668021930381656
# log Score for candidate 2055: 0.4708413300686516
# log Score for candidate 1762: 0.4794668336980976
# log Score for candidate 24739: 0.4200190508272499
# log Score for candidate 1168: 0.4200190508272499
# log Score for candidate 4534: 0.48980966093949974
# log Score for candidate 3035: 0.473654133209493
# log Score for candidate 8876: 0.37220013997284696
# log Score for candidate 10980: 0.3493762066354975
# log Score for candidate 24818: 0.6058331069070846
# log Score for candidate 1247: 0.6058331069070846
# log Score for candidate 4204: 0.35058516450226307
# log Score for candidate 6493: 0.35600805457215756
# log Score for candidate 20957: 0.35229057469405234
# log Score for candidate 12853: 0.34234814811497927
# log Score for candidate 22271: 0.3533964240923524
# log Score for candidate 15599: 0.43443858809769154
# log Score for candidate 1525: 0.3338125010486692
# log Score for candidate 1420: 0.35201236174907535
# log Score for candidate 19896: 0.3535821532132104
# log Score for candidate 12748: 0.3484389658551663
# log Score for candidate 4110: 0.6021143789985217
# log Score for candidate 21214: 0.4167902304325253

# %%
spectrum_mgf[query_idx]
# Out:
# {'PEPMASS': 434.128,
#  'SPECTRUMID': 'CCMSLIB00010124534',
#  'SCANS': '22098',
#  'peaks': array([[5.0090961e+01, 1.0042304e+00],
#         [6.0774689e+01, 1.0781515e+00],
#         [6.5412918e+01, 1.2108222e+00],
#         [6.7712196e+01, 1.0006795e+00],
#         [7.3937401e+01, 1.0300543e+00],
#         [9.7054321e+01, 1.1549778e+00],
#         [1.0305491e+02, 9.9293232e-01],
#         [1.0507028e+02, 2.0065238e+00],
#         [1.3006531e+02, 1.3763863e+01],
#         [1.3107298e+02, 1.3079849e+00],
#         [1.3502661e+02, 1.4793917e+00],
#         [1.4507605e+02, 5.9763165e+00],
#         [1.4807545e+02, 6.3746514e+00],
#         [1.5003694e+02, 5.0033975e+00],
#         [1.5707594e+02, 5.9772849e+00],
#         [1.5806006e+02, 1.0315715e+01],
#         [1.5808347e+02, 1.7337580e+00],
#         [1.5906750e+02, 5.2806826e+00],
#         [1.6007629e+02, 1.3564049e+00],
#         [1.6203705e+02, 7.3391129e+01],
#         [1.6405296e+02, 1.0123649e+01],
#         [1.6587277e+02, 1.1204382e+00],
#         [1.6907585e+02, 4.6676860e+00],
#         [1.7208678e+02, 2.3423002e+01],
#         [1.7403775e+02, 4.6250763e+00],
#         [1.7503232e+02, 8.6746006e+00],
#         [1.8305481e+02, 1.2799014e+00],
#         [1.8408641e+02, 9.2866287e+00],
#         [1.8490395e+02, 1.1875806e+00],
#         [1.8507135e+02, 2.0342846e+00],
#         [1.8509459e+02, 5.1528540e+00],
#         [1.8536537e+02, 1.2524635e+00],
#         [1.8607767e+02, 1.3680258e+00],
#         [1.8904797e+02, 6.5262703e+01],
#         [1.9003192e+02, 8.3244270e+01],
#         [1.9304295e+02, 3.3877846e+01],
#         [1.9806593e+02, 6.3068633e+00],
#         [1.9903278e+02, 1.5006965e+00],
#         [2.0204320e+02, 1.4354587e+01],
#         [2.0907961e+02, 1.0603975e+00],
#         [2.1107346e+02, 2.3812945e+00],
#         [2.1208171e+02, 2.5361383e+02],
#         [2.1308926e+02, 2.4810074e+01],
#         [2.1605873e+02, 3.9025532e+01],
#         [2.1704280e+02, 5.9430680e+00],
#         [2.2604312e+02, 1.2298675e+00],
#         [2.2805783e+02, 2.1117566e+00],
#         [2.3003806e+02, 1.2774966e+02],
#         [2.3707675e+02, 7.0838428e+00],
#         [2.3808469e+02, 2.4133162e+01],
#         [2.3909317e+02, 2.3167346e+00],
#         [2.4405363e+02, 7.2476184e+02],
#         [2.4607005e+02, 1.8877335e+00],
#         [2.5305438e+02, 8.0177031e+00],
#         [2.5603891e+02, 2.2156982e+00],
#         [2.5704874e+02, 5.9982666e+01],
#         [2.6206461e+02, 2.1501375e+01],
#         [2.7106442e+02, 4.2226544e+02],
#         [2.7204797e+02, 1.3328406e+00],
#         [2.9905936e+02, 9.9900000e+02],
#         [3.4365112e+02, 1.2243798e+00],
#         [3.9945483e+02, 1.3738362e+00],
#         [4.3412762e+02, 1.2368076e+01]], dtype=float32),
#  'CHARGE': 1,
#  'MSLEVEL': '2',
#  'SOURCE_INSTRUMENT': 'LC-ESI-Orbitrap',
#  'FILENAME': 'tharwood/spectral_libraries/BERKELEY-LAB.mgf',
#  'SEQ': '*..*',
#  'IONMODE': 'Positive',
#  'ORGANISM': 'BERKELEY-LAB',
#  'NAME': 'N-(4-acetylphenyl)-2-[9-(4-methylphenyl)-6-oxohydropurin-8-ylthio]acetamide CollisionEnergy:205060 M+H',
#  'PI': 'Trent Northen',
#  'DATACOLLECTOR': 'JGI',
#  'SMILES': 'CC(=O)c1ccc(NC(=O)CSc2nc3c(O)ncnc3n2-c2ccc(C)cc2)cc1',
#  'INCHI': '"InChI=1S/C22H19N5O3S/c1-13-3-9-17(10-4-13)27-20-19(21(30)24-12-23-20)26-22(27)31-11-18(29)25-16-7-5-15(6-8-16)14(2)28/h3-10,12H,11H2,1-2H3,(H,25,29)(H,23,24,30)"',
#  'INCHIAUX': 'N/A',
#  'PUBMED': 'N/A',
#  'SUBMITUSER': 'mwang87',
#  'LIBRARYQUALITY': '3',
#  'PRECURSOR_MZ': '434.128'}

# %%
for i in range(len(spectrum_mgf)):
    if int(spectrum_mgf[i]['SCANS']) == 22098:
        print("Found query spectrum at index:", i)
        query_idx = i
        break
# Out:
# Found query spectrum at index: 41

# %%
library_mgf[24925]
# Out:
# {'PEPMASS': 186.016,
#  'SPECTRUMID': 'CCMSLIB00010126959',
#  'SCANS': '24523',
#  'peaks': array([[ 53.7097   ,   1.4847158],
#         [ 60.5486   ,   1.4137611],
#         [ 69.446    ,   1.5775278],
#         [ 69.764    ,   1.4533497],
#         [ 70.0293   ,  31.554653 ],
#         [ 83.9781   ,   1.650699 ],
#         [ 88.0398   , 999.       ],
#         [ 94.6251   ,   1.5492384],
#         [104.305    ,   1.3858774],
#         [114.113    ,   1.4237576],
#         [140.011    ,   2.9121485],
#         [158.001    ,   1.7927151],
#         [166.703    ,   1.3578134],
#         [185.435    ,   2.3285198],
#         [186.016    ,  20.187632 ],
#         [186.185    ,   1.6886365]], dtype=float32),
#  'CHARGE': 1,
#  'MSLEVEL': '2',
#  'SOURCE_INSTRUMENT': 'LC-ESI-Orbitrap',
#  'FILENAME': 'tharwood/spectral_libraries/BERKELEY-LAB.mgf',
#  'SEQ': '*..*',
#  'IONMODE': 'Positive',
#  'ORGANISM': 'BERKELEY-LAB',
#  'NAME': 'O-phospho-L-serine CollisionEnergy:102040 M+H',
#  'PI': 'Trent Northen',
#  'DATACOLLECTOR': 'JGI',
#  'SMILES': 'N[C@@H](COP(=O)(O)O)C(=O)O',
#  'INCHI': '"InChI=1S/C3H8NO6P/c4-2(3(5)6)1-10-11(7,8)9/h2H,1,4H2,(H,5,6)(H2,7,8,9)/t2-/m0/s1"',
#  'INCHIAUX': 'N/A',
#  'PUBMED': 'N/A',
#  'SUBMITUSER': 'mwang87',
#  'LIBRARYQUALITY': '3',
#  'PRECURSOR_MZ': '186.016'}

# %%
library_mgf[10748]
# Out:
# {'PEPMASS': 392.185,
#  'SPECTRUMID': 'CCMSLIB00010112747',
#  'SCANS': '10313',
#  'peaks': array([[ 55.01869  ,   2.9565785],
#         [ 55.37616  ,   1.9496881],
#         [ 56.05012  ,   2.8142047],
#         [ 57.07058  ,  11.240429 ],
#         [ 58.99576  ,  13.415787 ],
#         [ 64.80334  ,   2.0496187],
#         [ 69.06844  ,   2.2629347],
#         [ 73.93755  ,   2.3781548],
#         [ 76.02232  ,  15.951238 ],
#         [ 76.04037  ,   2.5013251],
#         [ 77.79303  ,   2.0136585],
#         [ 81.07086  ,   2.6381946],
#         [ 82.37904  ,   2.6284096],
#         [ 82.38445  ,   2.2936356],
#         [ 83.08619  ,   4.535777 ],
#         [ 84.04508  ,  64.60917  ],
#         [ 85.10181  ,  18.420761 ],
#         [ 86.99043  ,  13.63216  ],
#         [100.11194  ,   2.446773 ],
#         [101.96172  ,   2.1557875],
#         [102.055    ,   2.991438 ],
#         [105.00076  ,   3.9253068],
#         [112.0397   ,   9.185551 ],
#         [116.01683  , 174.01921  ],
#         [127.09774  ,   2.2379827],
#         [129.0659   ,  26.16704  ],
#         [130.05005  ,  66.2105   ],
#         [143.07838  ,   3.0907571],
#         [143.08926  ,  34.974396 ],
#         [144.01152  , 174.99734  ],
#         [145.06058  ,   8.794512 ],
#         [160.11555  , 466.16724  ],
#         [162.02197  , 409.62823  ],
#         [189.09454  ,  11.349533 ],
#         [198.17699  ,   2.8696132],
#         [229.50977  ,   2.3595629],
#         [246.11581  , 999.       ],
#         [263.14227  , 429.70526  ],
#         [271.14627  ,   3.6830025],
#         [289.1588   ,   3.3572798],
#         [299.14255  ,   5.429649 ],
#         [303.03726  ,   2.6966608],
#         [317.15283  ,  83.88735  ],
#         [328.9759   ,   2.4313614],
#         [329.15393  ,  15.952094 ],
#         [374.1733   ,  12.470787 ],
#         [375.1557   ,   9.168794 ],
#         [392.18475  , 633.7508   ],
#         [405.7329   ,   2.3908753]], dtype=float32),
#  'CHARGE': 1,
#  'MSLEVEL': '2',
#  'SOURCE_INSTRUMENT': 'LC-ESI-Orbitrap',
#  'FILENAME': 'tharwood/spectral_libraries/BERKELEY-LAB.mgf',
#  'SEQ': '*..*',
#  'IONMODE': 'Positive',
#  'ORGANISM': 'BERKELEY-LAB',
#  'NAME': 's-hexylglutathione CollisionEnergy:102040 M+H',
#  'PI': 'Trent Northen',
#  'DATACOLLECTOR': 'JGI',
#  'SMILES': 'CCCCCCSCC(N=C(O)CCC(N)C(=O)O)C(O)=NCC(=O)O',
#  'INCHI': '"InChI=1S/C16H29N3O6S/c1-2-3-4-5-8-26-10-12(15(23)18-9-14(21)22)19-13(20)7-6-11(17)16(24)25/h11-12H,2-10,17H2,1H3,(H,18,23)(H,19,20)(H,21,22)(H,24,25)/t11-,12-/m0/s1"',
#  'INCHIAUX': 'N/A',
#  'PUBMED': 'N/A',
#  'SUBMITUSER': 'mwang87',
#  'LIBRARYQUALITY': '3',
#  'PRECURSOR_MZ': '392.185'}

# %%
df[df['SPECTRUMID'] == 'CCMSLIB00010121918']
# Out:
#        PEPMASS          SPECTRUMID  SCANS  \
# 19897  426.079  CCMSLIB00010121918  19483
#
#                                                    peaks  CHARGE MSLEVEL  \
# 19897  [[104.04935, 0.9985562], [105.06989, 1.6460254...       1       2
#
#       SOURCE_INSTRUMENT                                      FILENAME   SEQ  \
# 19897   LC-ESI-Orbitrap  tharwood/spectral_libraries/BERKELEY-LAB.mgf  *..*
#
#         IONMODE  ...                                               NAME  \
# 19897  Positive  ...  N-(4-chlorophenyl)-2-[9-(4-methylphenyl)-6-oxo...
#
#                   PI DATACOLLECTOR  \
# 19897  Trent Northen           JGI
#
#                                                   SMILES  \
# 19897  Cc1ccc(-n2c(SCC(=O)Nc3ccc(Cl)cc3)nc3c(O)ncnc32...
#
#                                                    INCHI INCHIAUX PUBMED  \
# 19897  "InChI=1S/C20H16ClN5O2S/c1-12-2-8-15(9-3-12)26...      N/A    N/A
#
#       SUBMITUSER LIBRARYQUALITY PRECURSOR_MZ
# 19897    mwang87              3      426.079
#
# [1 rows x 21 columns]

# %%
library_mgf[19897]
# Out:
# {'PEPMASS': 426.079,
#  'SPECTRUMID': 'CCMSLIB00010121918',
#  'SCANS': '19483',
#  'peaks': array([[1.0404935e+02, 9.9855620e-01],
#         [1.0506989e+02, 1.6460254e+00],
#         [1.1806535e+02, 1.3347471e+00],
#         [1.2524415e+02, 9.0558362e-01],
#         [1.3006508e+02, 1.1683723e+01],
#         [1.3107291e+02, 1.4374791e+00],
#         [1.3305276e+02, 9.6902072e-01],
#         [1.3502632e+02, 1.4369655e+00],
#         [1.4002617e+02, 1.2261078e+00],
#         [1.4507567e+02, 5.0477428e+00],
#         [1.4802115e+02, 1.0807419e+00],
#         [1.4807570e+02, 3.6757553e+00],
#         [1.4962625e+02, 7.8821218e-01],
#         [1.5003720e+02, 4.7919397e+00],
#         [1.5707527e+02, 7.1658220e+00],
#         [1.5796132e+02, 8.8991696e-01],
#         [1.5805939e+02, 8.9906015e+00],
#         [1.5808392e+02, 1.2777307e+00],
#         [1.5906776e+02, 5.7026601e+00],
#         [1.6007632e+02, 1.2076161e+00],
#         [1.6203699e+02, 7.7996796e+01],
#         [1.6304526e+02, 1.1850150e+00],
#         [1.6405270e+02, 1.0943026e+01],
#         [1.6600537e+02, 9.2767102e-01],
#         [1.6907605e+02, 4.8127427e+00],
#         [1.7208664e+02, 2.4787720e+01],
#         [1.7403705e+02, 4.0186238e+00],
#         [1.7503181e+02, 1.0190256e+01],
#         [1.8408675e+02, 9.9439554e+00],
#         [1.8507175e+02, 1.2959657e+00],
#         [1.8509502e+02, 4.2903500e+00],
#         [1.8904791e+02, 6.7918770e+01],
#         [1.9003185e+02, 7.8088997e+01],
#         [1.9304285e+02, 3.4168701e+01],
#         [1.9806618e+02, 8.8018312e+00],
#         [1.9903220e+02, 1.0018950e+00],
#         [2.0204333e+02, 1.7673521e+01],
#         [2.0705792e+02, 1.5563916e+00],
#         [2.1107385e+02, 4.1963501e+00],
#         [2.1208163e+02, 2.4387398e+02],
#         [2.1308939e+02, 2.3360001e+01],
#         [2.1605869e+02, 4.8607189e+01],
#         [2.1704338e+02, 6.3765826e+00],
#         [2.2702740e+02, 1.4451841e+00],
#         [2.3003795e+02, 1.2851993e+02],
#         [2.3707677e+02, 5.8942552e+00],
#         [2.3808427e+02, 2.5085642e+01],
#         [2.3909267e+02, 4.0936179e+00],
#         [2.4405354e+02, 7.2008307e+02],
#         [2.4607076e+02, 1.2384357e+00],
#         [2.4625116e+02, 9.0789509e-01],
#         [2.5305469e+02, 7.5967832e+00],
#         [2.5604062e+02, 4.3237381e+00],
#         [2.5704855e+02, 5.8733749e+01],
#         [2.6206369e+02, 2.1587614e+01],
#         [2.7106430e+02, 3.8410974e+02],
#         [2.7204840e+02, 1.1965723e+00],
#         [2.9905920e+02, 9.9900000e+02],
#         [3.2077036e+02, 9.8802614e-01],
#         [3.7388644e+02, 9.0250164e-01],
#         [4.2607843e+02, 1.2893138e+01]], dtype=float32),
#  'CHARGE': 1,
#  'MSLEVEL': '2',
#  'SOURCE_INSTRUMENT': 'LC-ESI-Orbitrap',
#  'FILENAME': 'tharwood/spectral_libraries/BERKELEY-LAB.mgf',
#  'SEQ': '*..*',
#  'IONMODE': 'Positive',
#  'ORGANISM': 'BERKELEY-LAB',
#  'NAME': 'N-(4-chlorophenyl)-2-[9-(4-methylphenyl)-6-oxohydropurin-8-ylthio]acetamide CollisionEnergy:205060 M+H',
#  'PI': 'Trent Northen',
#  'DATACOLLECTOR': 'JGI',
#  'SMILES': 'Cc1ccc(-n2c(SCC(=O)Nc3ccc(Cl)cc3)nc3c(O)ncnc32)cc1',
#  'INCHI': '"InChI=1S/C20H16ClN5O2S/c1-12-2-8-15(9-3-12)26-18-17(19(28)23-11-22-18)25-20(26)29-10-16(27)24-14-6-4-13(21)5-7-14/h2-9,11H,10H2,1H3,(H,24,27)(H,22,23,28)"',
#  'INCHIAUX': 'N/A',
#  'PUBMED': 'N/A',
#  'SUBMITUSER': 'mwang87',
#  'LIBRARYQUALITY': '3',
#  'PRECURSOR_MZ': '426.079'}

# %%
spectrum_mgf[41]
# Out:
# {'PEPMASS': 434.128,
#  'SPECTRUMID': 'CCMSLIB00010124534',
#  'SCANS': '22098',
#  'peaks': array([[5.0090961e+01, 1.0042304e+00],
#         [6.0774689e+01, 1.0781515e+00],
#         [6.5412918e+01, 1.2108222e+00],
#         [6.7712196e+01, 1.0006795e+00],
#         [7.3937401e+01, 1.0300543e+00],
#         [9.7054321e+01, 1.1549778e+00],
#         [1.0305491e+02, 9.9293232e-01],
#         [1.0507028e+02, 2.0065238e+00],
#         [1.3006531e+02, 1.3763863e+01],
#         [1.3107298e+02, 1.3079849e+00],
#         [1.3502661e+02, 1.4793917e+00],
#         [1.4507605e+02, 5.9763165e+00],
#         [1.4807545e+02, 6.3746514e+00],
#         [1.5003694e+02, 5.0033975e+00],
#         [1.5707594e+02, 5.9772849e+00],
#         [1.5806006e+02, 1.0315715e+01],
#         [1.5808347e+02, 1.7337580e+00],
#         [1.5906750e+02, 5.2806826e+00],
#         [1.6007629e+02, 1.3564049e+00],
#         [1.6203705e+02, 7.3391129e+01],
#         [1.6405296e+02, 1.0123649e+01],
#         [1.6587277e+02, 1.1204382e+00],
#         [1.6907585e+02, 4.6676860e+00],
#         [1.7208678e+02, 2.3423002e+01],
#         [1.7403775e+02, 4.6250763e+00],
#         [1.7503232e+02, 8.6746006e+00],
#         [1.8305481e+02, 1.2799014e+00],
#         [1.8408641e+02, 9.2866287e+00],
#         [1.8490395e+02, 1.1875806e+00],
#         [1.8507135e+02, 2.0342846e+00],
#         [1.8509459e+02, 5.1528540e+00],
#         [1.8536537e+02, 1.2524635e+00],
#         [1.8607767e+02, 1.3680258e+00],
#         [1.8904797e+02, 6.5262703e+01],
#         [1.9003192e+02, 8.3244270e+01],
#         [1.9304295e+02, 3.3877846e+01],
#         [1.9806593e+02, 6.3068633e+00],
#         [1.9903278e+02, 1.5006965e+00],
#         [2.0204320e+02, 1.4354587e+01],
#         [2.0907961e+02, 1.0603975e+00],
#         [2.1107346e+02, 2.3812945e+00],
#         [2.1208171e+02, 2.5361383e+02],
#         [2.1308926e+02, 2.4810074e+01],
#         [2.1605873e+02, 3.9025532e+01],
#         [2.1704280e+02, 5.9430680e+00],
#         [2.2604312e+02, 1.2298675e+00],
#         [2.2805783e+02, 2.1117566e+00],
#         [2.3003806e+02, 1.2774966e+02],
#         [2.3707675e+02, 7.0838428e+00],
#         [2.3808469e+02, 2.4133162e+01],
#         [2.3909317e+02, 2.3167346e+00],
#         [2.4405363e+02, 7.2476184e+02],
#         [2.4607005e+02, 1.8877335e+00],
#         [2.5305438e+02, 8.0177031e+00],
#         [2.5603891e+02, 2.2156982e+00],
#         [2.5704874e+02, 5.9982666e+01],
#         [2.6206461e+02, 2.1501375e+01],
#         [2.7106442e+02, 4.2226544e+02],
#         [2.7204797e+02, 1.3328406e+00],
#         [2.9905936e+02, 9.9900000e+02],
#         [3.4365112e+02, 1.2243798e+00],
#         [3.9945483e+02, 1.3738362e+00],
#         [4.3412762e+02, 1.2368076e+01]], dtype=float32),
#  'CHARGE': 1,
#  'MSLEVEL': '2',
#  'SOURCE_INSTRUMENT': 'LC-ESI-Orbitrap',
#  'FILENAME': 'tharwood/spectral_libraries/BERKELEY-LAB.mgf',
#  'SEQ': '*..*',
#  'IONMODE': 'Positive',
#  'ORGANISM': 'BERKELEY-LAB',
#  'NAME': 'N-(4-acetylphenyl)-2-[9-(4-methylphenyl)-6-oxohydropurin-8-ylthio]acetamide CollisionEnergy:205060 M+H',
#  'PI': 'Trent Northen',
#  'DATACOLLECTOR': 'JGI',
#  'SMILES': 'CC(=O)c1ccc(NC(=O)CSc2nc3c(O)ncnc3n2-c2ccc(C)cc2)cc1',
#  'INCHI': '"InChI=1S/C22H19N5O3S/c1-13-3-9-17(10-4-13)27-20-19(21(30)24-12-23-20)26-22(27)31-11-18(29)25-16-7-5-15(6-8-16)14(2)28/h3-10,12H,11H2,1-2H3,(H,25,29)(H,23,24,30)"',
#  'INCHIAUX': 'N/A',
#  'PUBMED': 'N/A',
#  'SUBMITUSER': 'mwang87',
#  'LIBRARYQUALITY': '3',
#  'PRECURSOR_MZ': '434.128'}

# %%
calculate_exact_score_GNPS(spectrum_list[41], library_list[22511], 0.5)
# Out:
# (0.9879885557747912, 0.9834920949360821, 0.004496460838709027, 47.0)

# %%
calculate_exact_score_GNPS(spectrum_list[41], library_list[19897], 0.5)
# Out:
# (0.9938496128888801, 0.9898371418239549, 0.004012471064925194, 47.0)

# %%
cand
# Out:
# (24925, 0.9660447175847366, 0.9660447175847366, 0.0, 21.0)

# %%
df1 = pd.read_csv("/home/user/LabData/Reza/Code/LibrarySearch_Workflow/bin/NextflowModules/bin/library_search/temp/34f610f3-39a7-35a8-aa4e-0db4017fda8d:__xianghu_tsv_rest.mgf.tsv", sep="\t")
df2 = pd.read_csv("/home/user/LabData/Reza/Code/LibrarySearch_Workflow/nf_output/merged_results.tsv", sep="\t")

# %%
df1[['#Scan#', 'LibrarySpectrumID']].merge(
    df2[['#Scan#', 'LibrarySpectrumID']],
    on=['#Scan#', 'LibrarySpectrumID'],
    how='outer'
)
# Out:
#     #Scan#   LibrarySpectrumID
# 0    22098  CCMSLIB00010121918
# 1    21787  CCMSLIB00010123542
# 2     2908  CCMSLIB00010107847
# 3    21219  CCMSLIB00010123751
# 4    14544  CCMSLIB00010119560
# ..     ...                 ...
# 57    3646  CCMSLIB00010114606
# 58    9218  CCMSLIB00010108213
# 59    9883  CCMSLIB00010108213
# 60   21210  CCMSLIB00010103108
# 61   20551  CCMSLIB00010103108
#
# [62 rows x 2 columns]
